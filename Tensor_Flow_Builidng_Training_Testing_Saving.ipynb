# %% [markdown]
# # Importing Dependencies

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Loading and Cleaning Data

# %%
data=pd.read_excel("tf_model/Concrete_Data.xls")
target_col=data.columns[-1]
features= data.columns[[0,4,7]]
X_train, X_test, y_train, y_test = train_test_split(data[features],data[target_col],train_size=0.7,random_state=3, shuffle=True)

# %% [markdown]
# # Building and Compiling Model

# %%
model= Sequential()
model.add(Dense(units=32, activation='relu', input_dim=len(X_train.columns)))
model.add(Dense(units=64, activation='sigmoid'))
model.add(Dense(units=1))

# %%
model.compile(loss='mse', metrics='mse')

# %% [markdown]
# # Training and Testing Model

# %%
model.fit(X_train,y_train,epochs=500,batch_size=100)
# Out:
# Epoch 1/500
# 8/8 [==============================] - 1s 3ms/step - loss: 1365.1455 - mse: 1365.1455
# Epoch 2/500
# 8/8 [==============================] - 0s 2ms/step - loss: 1250.6892 - mse: 1250.6892
# Epoch 3/500
# 8/8 [==============================] - 0s 3ms/step - loss: 1201.8463 - mse: 1201.8463
# Epoch 4/500
# 8/8 [==============================] - 0s 2ms/step - loss: 1150.1062 - mse: 1150.1062
# Epoch 5/500
# 8/8 [==============================] - 0s 3ms/step - loss: 1120.8241 - mse: 1120.8241
# Epoch 6/500
# 8/8 [==============================] - 0s 3ms/step - loss: 1101.5295 - mse: 1101.5294
# Epoch 7/500
# 8/8 [==============================] - 0s 2ms/step - loss: 1083.9718 - mse: 1083.9718
# Epoch 8/500
# 8/8 [==============================] - 0s 2ms/step - loss: 1065.7649 - mse: 1065.7649
# Epoch 9/500
# 8/8 [==============================] - 0s 3ms/step - loss: 1037.4718 - mse: 1037.4718
# Epoch 10/500
# ...

# %%
predictions=model.predict(X_test)
mse=mean_squared_error(y_test,predictions)
print("rmse:",mse**(1/2))
# Out:
# rmse: 10.452081133122443

# %% [markdown]
# # Saving and Reusing Model

# %%
model.save("tf_model")
# Out:
# INFO:tensorflow:Assets written to: tf_model/assets

# %%
del model

# %%
model=load_model("tf_model")
